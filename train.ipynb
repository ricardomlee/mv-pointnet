# %%
from data_loader import DataGenerator
from model_cls import PointNet
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from schedules import onetenth_50_75
import os
import matplotlib
matplotlib.use('AGG')
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 选择gpu
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
def plot_history(history, result_dir):
    plt.plot(history.history['acc'], marker='.')
    plt.plot(history.history['val_acc'], marker='.')
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend(['acc', 'val_acc'], loc='lower right')
    plt.savefig(os.path.join(result_dir, 'model_accuracy.png'))
    plt.close()

    plt.plot(history.history['loss'], marker='.')
    plt.plot(history.history['val_loss'], marker='.')
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.grid()
    plt.legend(['loss', 'val_loss'], loc='upper right')
    plt.savefig(os.path.join(result_dir, 'model_loss.png'))
    plt.close()


def save_history(history, result_dir):
    loss = history.history['loss']
    acc = history.history['acc']
    val_loss = history.history['val_loss']
    val_acc = history.history['val_acc']
    nb_epoch = len(acc)

    with open(os.path.join(result_dir, 'result.txt'), 'w') as fp:
        fp.write('epoch\tloss\tacc\tval_loss\tval_acc\n')
        for i in range(nb_epoch):
            fp.write('{}\t{}\t{}\t{}\t{}\n'.format(
                i, loss[i], acc[i], val_loss[i], val_acc[i]))
        fp.close()

# %%
nb_classes = 40
train_file = '/home/lab1102/liming/data/data_liming/ModelNet40/ply_data_train.h5'
test_file = '/home/lab1102/liming/data/data_liming/ModelNet40/ply_data_test.h5'

epochs = 100
batch_size = 32

train = DataGenerator(train_file, batch_size, nb_classes, train=True)
val = DataGenerator(test_file, batch_size, nb_classes, train=False)

model = PointNet(nb_classes)
model.summary()
lr = 0.0001
adam = Adam(lr=lr)
model.compile(optimizer=adam,
               loss='categorical_crossentropy',
               metrics=['accuracy'])
if not os.path.exists('./results/'):
     os.mkdir('./results/')
checkpoint = ModelCheckpoint('./results/pointnet.h5', monitor='val_acc',
                                 save_weights_only=True, save_best_only=True,
                                 verbose=1)
history = model.fit_generator(train.generator(),
                                  steps_per_epoch=9840 // batch_size,
                                  epochs=epochs,
                                  validation_data=val.generator(),
                                  validation_steps=2468 // batch_size,
                                  callbacks=[checkpoint, onetenth_50_75(lr)],
                                  verbose=1)

plot_history(history, './results/')
save_history(history, './results/')
model.save_weights('./results/pointnet_weights.h5')
# Out:
# WARNING:tensorflow:From /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2048, 3)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2048, 64)          256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048, 64)          256
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2048, 64)          4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2048, 64)          256
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 2048, 64)          4160
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2048, 64)          256
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 2048, 128)         8320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048, 128)         512
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 2048, 1024)        132096
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2048, 1024)        4096
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1, 1024)           0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 512)            524800
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1, 512)            2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 512)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 256)            131328
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1, 256)            1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 256)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 40)             10280
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 40)                0
# =================================================================
# Total params: 823,848
# Trainable params: 819,624
# Non-trainable params: 4,224
# _________________________________________________________________
# WARNING:tensorflow:From /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/lab1102/liming/.conda/envs/lm_point/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/100
# 307/307 [==============================] - 40s 130ms/step - loss: 3.2196 - acc: 0.2677 - val_loss: 1.8321 - val_acc: 0.4651
#
# Epoch 00001: val_acc improved from -inf to 0.46510, saving model to ./results/pointnet.h5
# Epoch 2/100
# 307/307 [==============================] - 35s 113ms/step - loss: 2.2861 - acc: 0.4215 - val_loss: 1.4802 - val_acc: 0.5893
#
# Epoch 00002: val_acc improved from 0.46510 to 0.58929, saving model to ./results/pointnet.h5
# Epoch 3/100
# 307/307 [==============================] - 38s 123ms/step - loss: 1.9371 - acc: 0.4901 - val_loss: 1.1994 - val_acc: 0.6713
#
# Epoch 00003: val_acc improved from 0.58929 to 0.67127, saving model to ./results/pointnet.h5
# Epoch 4/100
# 307/307 [==============================] - 34s 112ms/step - loss: 1.6799 - acc: 0.5474 - val_loss: 1.0093 - val_acc: 0.7159
#
# Epoch 00004: val_acc improved from 0.67127 to 0.71591, saving model to ./results/pointnet.h5
# Epoch 5/100
# 307/307 [==============================] - 34s 109ms/step - loss: 1.5271 - acc: 0.5806 - val_loss: 1.0132 - val_acc: 0.7171
#
# Epoch 00005: val_acc improved from 0.71591 to 0.71713, saving model to ./results/pointnet.h5
# Epoch 6/100
# 307/307 [==============================] - 37s 120ms/step - loss: 1.4150 - acc: 0.6132 - val_loss: 0.8882 - val_acc: 0.7589
#
# Epoch 00006: val_acc improved from 0.71713 to 0.75893, saving model to ./results/pointnet.h5
# Epoch 7/100
# 307/307 [==============================] - 38s 124ms/step - loss: 1.3262 - acc: 0.6355 - val_loss: 0.8734 - val_acc: 0.7463
#
# Epoch 00007: val_acc did not improve from 0.75893
# Epoch 8/100
# 307/307 [==============================] - 35s 114ms/step - loss: 1.2566 - acc: 0.6503 - val_loss: 0.9056 - val_acc: 0.7423
#
# Epoch 00008: val_acc did not improve from 0.75893
# Epoch 9/100
# 307/307 [==============================] - 35s 115ms/step - loss: 1.1734 - acc: 0.6714 - val_loss: 0.7680 - val_acc: 0.7796
#
# Epoch 00009: val_acc improved from 0.75893 to 0.77963, saving model to ./results/pointnet.h5
# Epoch 10/100
# 307/307 [==============================] - 36s 118ms/step - loss: 1.1305 - acc: 0.6819 - val_loss: 0.8243 - val_acc: 0.7589
#
# Epoch 00010: val_acc did not improve from 0.77963
# Epoch 11/100
# 307/307 [==============================] - 34s 110ms/step - loss: 1.0813 - acc: 0.6945 - val_loss: 0.8150 - val_acc: 0.7675
#
# Epoch 00011: val_acc did not improve from 0.77963
# Epoch 12/100
# 307/307 [==============================] - 35s 116ms/step - loss: 1.0480 - acc: 0.6958 - val_loss: 0.7337 - val_acc: 0.7833
#
# Epoch 00012: val_acc improved from 0.77963 to 0.78328, saving model to ./results/pointnet.h5
# Epoch 13/100
# 307/307 [==============================] - 36s 116ms/step - loss: 1.0162 - acc: 0.7126 - val_loss: 0.6983 - val_acc: 0.7918
#
# Epoch 00013: val_acc improved from 0.78328 to 0.79180, saving model to ./results/pointnet.h5
# Epoch 14/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.9756 - acc: 0.7201 - val_loss: 0.7846 - val_acc: 0.7699
#
# Epoch 00014: val_acc did not improve from 0.79180
# Epoch 15/100
# 307/307 [==============================] - 34s 111ms/step - loss: 0.9646 - acc: 0.7209 - val_loss: 0.7431 - val_acc: 0.7873
#
# Epoch 00015: val_acc did not improve from 0.79180
# Epoch 16/100
# 307/307 [==============================] - 35s 115ms/step - loss: 0.9478 - acc: 0.7279 - val_loss: 0.7414 - val_acc: 0.7772
#
# Epoch 00016: val_acc did not improve from 0.79180
# Epoch 17/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.9167 - acc: 0.7350 - val_loss: 0.6499 - val_acc: 0.8101
#
# Epoch 00017: val_acc improved from 0.79180 to 0.81006, saving model to ./results/pointnet.h5
# Epoch 18/100
# 307/307 [==============================] - 34s 112ms/step - loss: 0.8894 - acc: 0.7404 - val_loss: 0.6816 - val_acc: 0.7934
#
# Epoch 00018: val_acc did not improve from 0.81006
# Epoch 19/100
# 307/307 [==============================] - 37s 122ms/step - loss: 0.8819 - acc: 0.7482 - val_loss: 0.6271 - val_acc: 0.8137
#
# Epoch 00019: val_acc improved from 0.81006 to 0.81372, saving model to ./results/pointnet.h5
# Epoch 20/100
# 307/307 [==============================] - 34s 112ms/step - loss: 0.8472 - acc: 0.7509 - val_loss: 0.6563 - val_acc: 0.8076
#
# Epoch 00020: val_acc did not improve from 0.81372
# Epoch 21/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.8568 - acc: 0.7533 - val_loss: 0.7606 - val_acc: 0.7711
#
# Epoch 00021: val_acc did not improve from 0.81372
# Epoch 22/100
# 307/307 [==============================] - 34s 110ms/step - loss: 0.8306 - acc: 0.7594 - val_loss: 0.6171 - val_acc: 0.8097
#
# Epoch 00022: val_acc did not improve from 0.81372
# Epoch 23/100
# 307/307 [==============================] - 36s 116ms/step - loss: 0.8114 - acc: 0.7602 - val_loss: 0.6684 - val_acc: 0.8064
#
# Epoch 00023: val_acc did not improve from 0.81372
# Epoch 24/100
# 307/307 [==============================] - 36s 117ms/step - loss: 0.8022 - acc: 0.7665 - val_loss: 0.7417 - val_acc: 0.7877
#
# Epoch 00024: val_acc did not improve from 0.81372
# Epoch 25/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.7867 - acc: 0.7700 - val_loss: 0.5814 - val_acc: 0.8255
#
# Epoch 00025: val_acc improved from 0.81372 to 0.82549, saving model to ./results/pointnet.h5
# Epoch 26/100
# 307/307 [==============================] - 35s 113ms/step - loss: 0.7777 - acc: 0.7725 - val_loss: 0.7085 - val_acc: 0.7886
#
# Epoch 00026: val_acc did not improve from 0.82549
# Epoch 27/100
# 307/307 [==============================] - 34s 110ms/step - loss: 0.7678 - acc: 0.7735 - val_loss: 0.6216 - val_acc: 0.8182
#
# Epoch 00027: val_acc did not improve from 0.82549
# Epoch 28/100
# 307/307 [==============================] - 37s 120ms/step - loss: 0.7483 - acc: 0.7763 - val_loss: 0.5436 - val_acc: 0.8401
#
# Epoch 00028: val_acc improved from 0.82549 to 0.84010, saving model to ./results/pointnet.h5
# Epoch 29/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.7585 - acc: 0.7820 - val_loss: 0.6222 - val_acc: 0.8162
#
# Epoch 00029: val_acc did not improve from 0.84010
# Epoch 30/100
# 307/307 [==============================] - 33s 108ms/step - loss: 0.7269 - acc: 0.7877 - val_loss: 0.5983 - val_acc: 0.8068
#
# Epoch 00030: val_acc did not improve from 0.84010
# Epoch 31/100
# 307/307 [==============================] - 37s 121ms/step - loss: 0.7195 - acc: 0.7858 - val_loss: 0.6165 - val_acc: 0.8194
#
# Epoch 00031: val_acc did not improve from 0.84010
# Epoch 32/100
# 307/307 [==============================] - 34s 112ms/step - loss: 0.7081 - acc: 0.7872 - val_loss: 0.7032 - val_acc: 0.7983
#
# Epoch 00032: val_acc did not improve from 0.84010
# Epoch 33/100
# 307/307 [==============================] - 34s 111ms/step - loss: 0.7138 - acc: 0.7904 - val_loss: 0.5982 - val_acc: 0.8259
#
# Epoch 00033: val_acc did not improve from 0.84010
# Epoch 34/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.7027 - acc: 0.7936 - val_loss: 0.5656 - val_acc: 0.8226
#
# Epoch 00034: val_acc did not improve from 0.84010
# Epoch 35/100
# 307/307 [==============================] - 38s 123ms/step - loss: 0.7013 - acc: 0.7897 - val_loss: 0.6483 - val_acc: 0.8056
#
# Epoch 00035: val_acc did not improve from 0.84010
# Epoch 36/100
# 307/307 [==============================] - 34s 112ms/step - loss: 0.6737 - acc: 0.7976 - val_loss: 0.7522 - val_acc: 0.7812
#
# Epoch 00036: val_acc did not improve from 0.84010
# Epoch 37/100
# 307/307 [==============================] - 34s 109ms/step - loss: 0.6631 - acc: 0.8012 - val_loss: 0.5202 - val_acc: 0.8364
#
# Epoch 00037: val_acc did not improve from 0.84010
# Epoch 38/100
# 307/307 [==============================] - 37s 119ms/step - loss: 0.6534 - acc: 0.8019 - val_loss: 0.5680 - val_acc: 0.8373
#
# Epoch 00038: val_acc did not improve from 0.84010
# Epoch 39/100
# 307/307 [==============================] - 36s 116ms/step - loss: 0.6585 - acc: 0.7984 - val_loss: 0.5414 - val_acc: 0.8438
#
# Epoch 00039: val_acc improved from 0.84010 to 0.84375, saving model to ./results/pointnet.h5
# Epoch 40/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.6404 - acc: 0.8048 - val_loss: 0.5401 - val_acc: 0.8373
#
# Epoch 00040: val_acc did not improve from 0.84375
# Epoch 41/100
# 307/307 [==============================] - 34s 112ms/step - loss: 0.6441 - acc: 0.8029 - val_loss: 0.5782 - val_acc: 0.8218
#
# Epoch 00041: val_acc did not improve from 0.84375
# Epoch 42/100
# 307/307 [==============================] - 34s 111ms/step - loss: 0.6447 - acc: 0.8077 - val_loss: 0.5395 - val_acc: 0.8409
#
# Epoch 00042: val_acc did not improve from 0.84375
# Epoch 43/100
# 307/307 [==============================] - 37s 120ms/step - loss: 0.6369 - acc: 0.8078 - val_loss: 0.5182 - val_acc: 0.8454
#
# Epoch 00043: val_acc improved from 0.84375 to 0.84537, saving model to ./results/pointnet.h5
# Epoch 44/100
# 307/307 [==============================] - 34s 109ms/step - loss: 0.6147 - acc: 0.8169 - val_loss: 0.7252 - val_acc: 0.7821
#
# Epoch 00044: val_acc did not improve from 0.84537
# Epoch 45/100
# 307/307 [==============================] - 35s 115ms/step - loss: 0.6261 - acc: 0.8129 - val_loss: 0.6007 - val_acc: 0.8129
#
# Epoch 00045: val_acc did not improve from 0.84537
# Epoch 46/100
# 307/307 [==============================] - 38s 122ms/step - loss: 0.6263 - acc: 0.8113 - val_loss: 0.5574 - val_acc: 0.8356
#
# Epoch 00046: val_acc did not improve from 0.84537
# Epoch 47/100
# 307/307 [==============================] - 34s 112ms/step - loss: 0.6066 - acc: 0.8149 - val_loss: 0.5522 - val_acc: 0.8332
#
# Epoch 00047: val_acc did not improve from 0.84537
# Epoch 48/100
# 307/307 [==============================] - 36s 117ms/step - loss: 0.6112 - acc: 0.8130 - val_loss: 0.5806 - val_acc: 0.8226
#
# Epoch 00048: val_acc did not improve from 0.84537
# Epoch 49/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.6046 - acc: 0.8132 - val_loss: 0.6259 - val_acc: 0.8072
#
# Epoch 00049: val_acc did not improve from 0.84537
# Epoch 50/100
# 307/307 [==============================] - 33s 108ms/step - loss: 0.6050 - acc: 0.8161 - val_loss: 0.5918 - val_acc: 0.8198
#
# Epoch 00050: val_acc did not improve from 0.84537
# Epoch 51/100
# 307/307 [==============================] - 34s 111ms/step - loss: 0.5762 - acc: 0.8235 - val_loss: 0.4504 - val_acc: 0.8685
#
# Epoch 00051: val_acc improved from 0.84537 to 0.86851, saving model to ./results/pointnet.h5
# Epoch 52/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.5581 - acc: 0.8330 - val_loss: 0.4541 - val_acc: 0.8624
#
# Epoch 00052: val_acc did not improve from 0.86851
# Epoch 53/100
# 307/307 [==============================] - 38s 122ms/step - loss: 0.5483 - acc: 0.8353 - val_loss: 0.4439 - val_acc: 0.8693
#
# Epoch 00053: val_acc improved from 0.86851 to 0.86932, saving model to ./results/pointnet.h5
# Epoch 54/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.5404 - acc: 0.8350 - val_loss: 0.4490 - val_acc: 0.8742
#
# Epoch 00054: val_acc improved from 0.86932 to 0.87419, saving model to ./results/pointnet.h5
# Epoch 55/100
# 307/307 [==============================] - 35s 115ms/step - loss: 0.5483 - acc: 0.8344 - val_loss: 0.4472 - val_acc: 0.8705
#
# Epoch 00055: val_acc did not improve from 0.87419
# Epoch 56/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.5420 - acc: 0.8330 - val_loss: 0.4463 - val_acc: 0.8689
#
# Epoch 00056: val_acc did not improve from 0.87419
# Epoch 57/100
# 307/307 [==============================] - 32s 104ms/step - loss: 0.5248 - acc: 0.8401 - val_loss: 0.4501 - val_acc: 0.8653
#
# Epoch 00057: val_acc did not improve from 0.87419
# Epoch 58/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.5270 - acc: 0.8397 - val_loss: 0.4429 - val_acc: 0.8701
#
# Epoch 00058: val_acc did not improve from 0.87419
# Epoch 59/100
# 307/307 [==============================] - 36s 116ms/step - loss: 0.5269 - acc: 0.8386 - val_loss: 0.4424 - val_acc: 0.8689
#
# Epoch 00059: val_acc did not improve from 0.87419
# Epoch 60/100
# 307/307 [==============================] - 35s 113ms/step - loss: 0.5186 - acc: 0.8379 - val_loss: 0.4405 - val_acc: 0.8693
#
# Epoch 00060: val_acc did not improve from 0.87419
# Epoch 61/100
# 307/307 [==============================] - 37s 120ms/step - loss: 0.5281 - acc: 0.8383 - val_loss: 0.4433 - val_acc: 0.8693
#
# Epoch 00061: val_acc did not improve from 0.87419
# Epoch 62/100
# 307/307 [==============================] - 32s 105ms/step - loss: 0.5170 - acc: 0.8376 - val_loss: 0.4431 - val_acc: 0.8726
#
# Epoch 00062: val_acc did not improve from 0.87419
# Epoch 63/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.5182 - acc: 0.8376 - val_loss: 0.4485 - val_acc: 0.8701
#
# Epoch 00063: val_acc did not improve from 0.87419
# Epoch 64/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.5068 - acc: 0.8435 - val_loss: 0.4490 - val_acc: 0.8669
#
# Epoch 00064: val_acc did not improve from 0.87419
# Epoch 65/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.5228 - acc: 0.8399 - val_loss: 0.4470 - val_acc: 0.8701
#
# Epoch 00065: val_acc did not improve from 0.87419
# Epoch 66/100
# 307/307 [==============================] - 35s 113ms/step - loss: 0.5159 - acc: 0.8415 - val_loss: 0.4384 - val_acc: 0.8722
#
# Epoch 00066: val_acc did not improve from 0.87419
# Epoch 67/100
# 307/307 [==============================] - 37s 121ms/step - loss: 0.4983 - acc: 0.8459 - val_loss: 0.4365 - val_acc: 0.8713
#
# Epoch 00067: val_acc did not improve from 0.87419
# Epoch 68/100
# 307/307 [==============================] - 35s 113ms/step - loss: 0.5281 - acc: 0.8374 - val_loss: 0.4334 - val_acc: 0.8746
#
# Epoch 00068: val_acc improved from 0.87419 to 0.87459, saving model to ./results/pointnet.h5
# Epoch 69/100
# 307/307 [==============================] - 35s 113ms/step - loss: 0.5139 - acc: 0.8404 - val_loss: 0.4406 - val_acc: 0.8697
#
# Epoch 00069: val_acc did not improve from 0.87459
# Epoch 70/100
# 307/307 [==============================] - 33s 107ms/step - loss: 0.5058 - acc: 0.8452 - val_loss: 0.4407 - val_acc: 0.8718
#
# Epoch 00070: val_acc did not improve from 0.87459
# Epoch 71/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.5026 - acc: 0.8463 - val_loss: 0.4406 - val_acc: 0.8718
#
# Epoch 00071: val_acc did not improve from 0.87459
# Epoch 72/100
# 307/307 [==============================] - 34s 110ms/step - loss: 0.5074 - acc: 0.8443 - val_loss: 0.4381 - val_acc: 0.8726
#
# Epoch 00072: val_acc did not improve from 0.87459
# Epoch 73/100
# 307/307 [==============================] - 34s 112ms/step - loss: 0.5027 - acc: 0.8442 - val_loss: 0.4430 - val_acc: 0.8661
#
# Epoch 00073: val_acc did not improve from 0.87459
# Epoch 74/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.5127 - acc: 0.8423 - val_loss: 0.4378 - val_acc: 0.8750
#
# Epoch 00074: val_acc improved from 0.87459 to 0.87500, saving model to ./results/pointnet.h5
# Epoch 75/100
# 307/307 [==============================] - 35s 113ms/step - loss: 0.5038 - acc: 0.8479 - val_loss: 0.4353 - val_acc: 0.8734
#
# Epoch 00075: val_acc did not improve from 0.87500
# Epoch 76/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.4962 - acc: 0.8465 - val_loss: 0.4368 - val_acc: 0.8738
#
# Epoch 00076: val_acc did not improve from 0.87500
# Epoch 77/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.5023 - acc: 0.8505 - val_loss: 0.4362 - val_acc: 0.8734
#
# Epoch 00077: val_acc did not improve from 0.87500
# Epoch 78/100
# 307/307 [==============================] - 37s 120ms/step - loss: 0.4947 - acc: 0.8462 - val_loss: 0.4358 - val_acc: 0.8742
#
# Epoch 00078: val_acc did not improve from 0.87500
# Epoch 79/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.5051 - acc: 0.8429 - val_loss: 0.4345 - val_acc: 0.8734
#
# Epoch 00079: val_acc did not improve from 0.87500
# Epoch 80/100
# 307/307 [==============================] - 34s 112ms/step - loss: 0.4919 - acc: 0.8497 - val_loss: 0.4350 - val_acc: 0.8750
#
# Epoch 00080: val_acc did not improve from 0.87500
# Epoch 81/100
# 307/307 [==============================] - 36s 117ms/step - loss: 0.4987 - acc: 0.8465 - val_loss: 0.4341 - val_acc: 0.8742
#
# Epoch 00081: val_acc did not improve from 0.87500
# Epoch 82/100
# 307/307 [==============================] - 35s 113ms/step - loss: 0.5010 - acc: 0.8461 - val_loss: 0.4334 - val_acc: 0.8754
#
# Epoch 00082: val_acc improved from 0.87500 to 0.87541, saving model to ./results/pointnet.h5
# Epoch 83/100
# 307/307 [==============================] - 35s 113ms/step - loss: 0.4884 - acc: 0.8517 - val_loss: 0.4340 - val_acc: 0.8742
#
# Epoch 00083: val_acc did not improve from 0.87541
# Epoch 84/100
# 307/307 [==============================] - 34s 111ms/step - loss: 0.4931 - acc: 0.8477 - val_loss: 0.4341 - val_acc: 0.8746
#
# Epoch 00084: val_acc did not improve from 0.87541
# Epoch 85/100
# 307/307 [==============================] - 34s 112ms/step - loss: 0.4846 - acc: 0.8509 - val_loss: 0.4356 - val_acc: 0.8746
#
# Epoch 00085: val_acc did not improve from 0.87541
# Epoch 86/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.4918 - acc: 0.8497 - val_loss: 0.4338 - val_acc: 0.8742
#
# Epoch 00086: val_acc did not improve from 0.87541
# Epoch 87/100
# 307/307 [==============================] - 35s 115ms/step - loss: 0.4970 - acc: 0.8423 - val_loss: 0.4342 - val_acc: 0.8738
#
# Epoch 00087: val_acc did not improve from 0.87541
# Epoch 88/100
# 307/307 [==============================] - 36s 118ms/step - loss: 0.4889 - acc: 0.8442 - val_loss: 0.4330 - val_acc: 0.8746
#
# Epoch 00088: val_acc did not improve from 0.87541
# Epoch 89/100
# 307/307 [==============================] - 35s 115ms/step - loss: 0.5030 - acc: 0.8488 - val_loss: 0.4325 - val_acc: 0.8762
#
# Epoch 00089: val_acc improved from 0.87541 to 0.87622, saving model to ./results/pointnet.h5
# Epoch 90/100
# 307/307 [==============================] - 38s 124ms/step - loss: 0.4904 - acc: 0.8514 - val_loss: 0.4334 - val_acc: 0.8750
#
# Epoch 00090: val_acc did not improve from 0.87622
# Epoch 91/100
# 307/307 [==============================] - 33s 106ms/step - loss: 0.4893 - acc: 0.8508 - val_loss: 0.4332 - val_acc: 0.8750
#
# Epoch 00091: val_acc did not improve from 0.87622
# Epoch 92/100
# 307/307 [==============================] - 34s 111ms/step - loss: 0.4957 - acc: 0.8476 - val_loss: 0.4338 - val_acc: 0.8754
#
# Epoch 00092: val_acc did not improve from 0.87622
# Epoch 93/100
# 307/307 [==============================] - 36s 116ms/step - loss: 0.5078 - acc: 0.8446 - val_loss: 0.4351 - val_acc: 0.8746
#
# Epoch 00093: val_acc did not improve from 0.87622
# Epoch 94/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.5016 - acc: 0.8500 - val_loss: 0.4336 - val_acc: 0.8754
#
# Epoch 00094: val_acc did not improve from 0.87622
# Epoch 95/100
# 307/307 [==============================] - 37s 119ms/step - loss: 0.4981 - acc: 0.8454 - val_loss: 0.4333 - val_acc: 0.8742
#
# Epoch 00095: val_acc did not improve from 0.87622
# Epoch 96/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.4920 - acc: 0.8476 - val_loss: 0.4321 - val_acc: 0.8746
#
# Epoch 00096: val_acc did not improve from 0.87622
# Epoch 97/100
# 307/307 [==============================] - 35s 114ms/step - loss: 0.4937 - acc: 0.8496 - val_loss: 0.4347 - val_acc: 0.8742
#
# Epoch 00097: val_acc did not improve from 0.87622
# Epoch 98/100
# 307/307 [==============================] - 36s 116ms/step - loss: 0.5063 - acc: 0.8458 - val_loss: 0.4337 - val_acc: 0.8746
#
# Epoch 00098: val_acc did not improve from 0.87622
# Epoch 99/100
# 307/307 [==============================] - 34s 111ms/step - loss: 0.4908 - acc: 0.8449 - val_loss: 0.4341 - val_acc: 0.8742
#
# Epoch 00099: val_acc did not improve from 0.87622
# Epoch 100/100
# 307/307 [==============================] - 35s 113ms/step - loss: 0.4800 - acc: 0.8503 - val_loss: 0.4324 - val_acc: 0.8750
#
# Epoch 00100: val_acc did not improve from 0.87622
